# %% [markdown]
# ### Transformada de Fourier

# %%
# importing the fft and inverse fft functions from fftpackage  
from scipy.fftpack import fft  
#Importing numpy  
import numpy as np  
#create an array with random n numbers  
x = np.random.rand(20)  
#Applying the fft function  
y = fft(x)  
print(x)
print(y)
# Out:
# [0.87337116 0.34429827 0.90722081 0.11804985 0.06298587 0.61400524
#  0.3745959  0.94985892 0.25580447 0.99598008 0.76216937 0.17945524
#  0.97954042 0.20767405 0.58008341 0.98251484 0.32120096 0.69788201
#  0.63353691 0.81776029]
# [11.65798806-0.j         -0.03151607+0.8366926j   1.09495598+1.09793801j
#   0.79538145-0.54075561j  0.52563757-0.18662727j -0.76470353+0.18779949j
#  -0.9189201 +1.08620389j  0.16134285-0.85169038j  1.72551993+2.93315831j
#   0.39550424-0.57439008j -0.15696954-0.j          0.39550424+0.57439008j
#   1.72551993-2.93315831j  0.16134285+0.85169038j -0.9189201 -1.08620389j
#  -0.76470353-0.18779949j  0.52563757+0.18662727j  0.79538145+0.54075561j
#   1.09495598-1.09793801j -0.03151607-0.8366926j ]

# %%
x = np.random.rand(20)  
print(x.ndim) #Dimension del array 
print (x.shape) #Forma del array
print (x.size) #Tamaño del array
# Out:
# 1
# (20,)
# 20

# %% [markdown]
# ### Constantes físicas

# %%
from scipy import constants as C
C.c  # Velocidad de la luz en m/s
C.e  #Euler
C.Avogadro #Número de avogradro
C.Planck #Constante de plank
C.m_e #Masa del electrón
# Out:
# 9.1093837015e-31

# %% [markdown]
# ### Interpolación

# %%
from scipy.interpolate import interp1d
import matplotlib.pyplot as plt

datos_x = np.arange(0, 0.1, 0.005)
A, k, theta = 10.0, 33.3, np.pi/5.0
y_real = A*np.sin(2*np.pi*k*datos_x + theta)
datos_y = y_real + 2*np.random.randn(len(datos_x))

interpolador_lineal = interp1d(datos_x, datos_y)


x_inter = np.linspace(0.012, 0.09, 500)
y_inter_l = interpolador_lineal(x_inter)


plt.plot(datos_x, datos_y, 'ok', label="Datos")
plt.plot(x_inter, y_inter_l, 'r', label="Interpolación lineal")
plt.title("Interpolación")
plt.xlim(-0.003, 0.102)
plt.ylim(-14, 15)
plt.legend()

# %% [markdown]
# ### Inputs y outputs en scipy

# %%
import scipy.io as sio   
#Guardar un archivo .mat  
sio.savemat('python.mat', {'A1': [0, 1, 2], 'A2': 0, 'A3': [7,9,8]})

#Cargar un archivo .mat    
mat_file_content = sio.loadmat('python.mat')  
print(sio.whosmat('python.mat'))
print(mat_file_content.keys())
mat_file_content['A1'].mean()
# Out:
# [('A1', (1, 3), 'int32'), ('A2', (1, 1), 'int32'), ('A3', (1, 3), 'int32')]
# dict_keys(['__header__', '__version__', '__globals__', 'A1', 'A2', 'A3'])
# 1.0
